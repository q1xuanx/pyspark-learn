# %% [markdown]
# PySpark làm quen với DataFrame

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

# %%
from datetime import datetime, date
from pyspark.sql import Row

df = spark.createDataFrame(
    [
      Row(a=1, b=2., c='string1', d=date(2000, 1, 1), e=datetime(2000, 1, 1, 12, 0)),
      Row(a=2, b=3., c='string2', d=date(2000, 2, 1), e=datetime(2000, 1, 2, 12, 0)),
      Row(a=4, b=5., c='string3', d=date(2000, 3, 1), e=datetime(2000, 1, 3, 12, 0))
    ]
)

# %%
df.show()

#Limit row show
df.show(2) # Show 2 row
# Out:
# +---+---+-------+----------+-------------------+
# |  a|  b|      c|         d|                  e|
# +---+---+-------+----------+-------------------+
# |  1|2.0|string1|2000-01-01|2000-01-01 12:00:00|
# |  2|3.0|string2|2000-02-01|2000-01-02 12:00:00|
# |  4|5.0|string3|2000-03-01|2000-01-03 12:00:00|
# +---+---+-------+----------+-------------------+
#
# +---+---+-------+----------+-------------------+
# |  a|  b|      c|         d|                  e|
# +---+---+-------+----------+-------------------+
# |  1|2.0|string1|2000-01-01|2000-01-01 12:00:00|
# |  2|3.0|string2|2000-02-01|2000-01-02 12:00:00|
# +---+---+-------+----------+-------------------+
# only showing top 2 rows

# %%
df.columns

df.select('a', 'b', 'c').describe().show()
# Out:
# +-------+------------------+------------------+-------+
# |summary|                 a|                 b|      c|
# +-------+------------------+------------------+-------+
# |  count|                 3|                 3|      3|
# |   mean|2.3333333333333335|3.3333333333333335|   NULL|
# | stddev|1.5275252316519465|1.5275252316519465|   NULL|
# |    min|                 1|               2.0|string1|
# |    max|                 4|               5.0|string3|
# +-------+------------------+------------------+-------+

# %%
df.toPandas()
# Out:
#    a    b        c           d                   e
# 0  1  2.0  string1  2000-01-01 2000-01-01 12:00:00
# 1  2  3.0  string2  2000-02-01 2000-01-02 12:00:00
# 2  4  5.0  string3  2000-03-01 2000-01-03 12:00:00

# %%
from pyspark.sql.functions import upper
df.withColumn('upper_c', upper(df.c)).show()
# Out:
# +---+---+-------+----------+-------------------+-------+
# |  a|  b|      c|         d|                  e|upper_c|
# +---+---+-------+----------+-------------------+-------+
# |  1|2.0|string1|2000-01-01|2000-01-01 12:00:00|STRING1|
# |  2|3.0|string2|2000-02-01|2000-01-02 12:00:00|STRING2|
# |  4|5.0|string3|2000-03-01|2000-01-03 12:00:00|STRING3|
# +---+---+-------+----------+-------------------+-------+

# %%
df.select(df.b).show()
# Out:
# +---+
# |  b|
# +---+
# |2.0|
# |3.0|
# |5.0|
# +---+

# %% [markdown]
# PySpark với function

# %%
def pandas_filter_func(interator):
  for pandas_df in interator:
    yield pandas_df[pandas_df.a == 4]

df.mapInPandas(pandas_filter_func, schema=df.schema).show()
# Out:
# +---+---+-------+----------+-------------------+
# |  a|  b|      c|         d|                  e|
# +---+---+-------+----------+-------------------+
# |  4|5.0|string3|2000-03-01|2000-01-03 12:00:00|
# +---+---+-------+----------+-------------------+

# %% [markdown]
# Group Data

# %%
df1 = spark.createDataFrame(
    [
      ['red', 'banana', 1, 10], ['blue', 'banana', 2, 20], ['red', 'carrot', 3, 30],
      ['blue', 'grape', 4, 40], ['red', 'carrot', 5, 50], ['black', 'carrot', 6, 60],
      ['red', 'banana', 7, 70], ['red', 'grape', 8, 80]
    ], schema=['color', 'fruit', 'v1', 'v2']
)
df1.toPandas()
# Out:
#    color   fruit  v1  v2
# 0    red  banana   1  10
# 1   blue  banana   2  20
# 2    red  carrot   3  30
# 3   blue   grape   4  40
# 4    red  carrot   5  50
# 5  black  carrot   6  60
# 6    red  banana   7  70
# 7    red   grape   8  80

# %%
df1.groupby('fruit').sum().show()
# Out:
# +------+-------+-------+
# | fruit|sum(v1)|sum(v2)|
# +------+-------+-------+
# | grape|     12|    120|
# |banana|     10|    100|
# |carrot|     14|    140|
# +------+-------+-------+

# %%
def plus_mean(pandas_df):
    print(pandas_df.v1.mean())
    return pandas_df.assign(v1=pandas_df.v1 - pandas_df.v1.mean(), v2=pandas_df.v2 - pandas_df.v2.mean())
df1.groupBy('fruit').applyInPandas(plus_mean, schema=df1.schema).show()
# Out:
# +-----+------+---+---+
# |color| fruit| v1| v2|
# +-----+------+---+---+
# |  red|banana| -2| 10|
# | blue|banana| -1| 20|
# |  red|banana|  3| 70|
# |  red|carrot| -1| 30|
# |  red|carrot|  0| 50|
# |black|carrot|  1| 60|
# | blue| grape| -2| 40|
# |  red| grape|  2| 80|
# +-----+------+---+---+

# %% [markdown]
# Practice with sample CSV File

# %%
zip_code_df = spark.read.option('header', 'true').csv('zipcodes.csv', inferSchema=True)
zip_code_df.show()
# Out:
# +------------+-------+-----------+-------------------+-----+--------------+-----+-------+-----+-----+-----+-----------+-------+--------------------+--------------------+-------------+---------------+-------------------+----------+-------------+
# |RecordNumber|Zipcode|ZipCodeType|               City|State|  LocationType|  Lat|   Long|Xaxis|Yaxis|Zaxis|WorldRegion|Country|        LocationText|            Location|Decommisioned|TaxReturnsFiled|EstimatedPopulation|TotalWages|        Notes|
# +------------+-------+-----------+-------------------+-----+--------------+-----+-------+-----+-----+-----+-----------+-------+--------------------+--------------------+-------------+---------------+-------------------+----------+-------------+
# |           1|    704|   STANDARD|        PARC PARQUE|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US|     Parc Parque, PR|NA-US-PR-PARC PARQUE|        false|           NULL|               NULL|      NULL|         NULL|
# |           2|    704|   STANDARD|PASEO COSTA DEL SUR|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US|Paseo Costa Del S...|NA-US-PR-PASEO CO...|        false|           NULL|               NULL|      NULL|         NULL|
# |          10|    709|   STANDARD|       BDA SAN LUIS|   PR|NOT ACCEPTABLE|18.14| -66.26| 0.38|-0.86| 0.31|         NA|     US|    Bda San Luis, PR|NA-US-PR-BDA SAN ...|        false|           NULL|               NULL|      NULL|         NULL|
# |       61391|  76166|     UNIQUE|  CINGULAR WIRELESS|   TX|NOT ACCEPTABLE|32.72| -97.31| -0.1|-0.83| 0.54|         NA|     US|Cingular Wireless...|NA-US-TX-CINGULAR...|        false|           NULL|               NULL|      NULL|         NULL|
# |       61392|  76177|   STANDARD|         FORT WORTH|   TX|       PRIMARY|32.75| -97.33| -0.1|-0.83| 0.54|         NA|     US|      Fort Worth, TX| NA-US-TX-FORT WORTH|        false|           2126|               4053| 122396986|         NULL|
# |       61393|  76177|   STANDARD|           FT WORTH|   TX|    ACCEPTABLE|32.75| -97.33| -0.1|-0.83| 0.54|         NA|     US|        Ft Worth, TX|   NA-US-TX-FT WORTH|        false|           2126|               4053| 122396986|         NULL|
# |           4|    704|   STANDARD|    URB EUGENE RICE|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US| Urb Eugene Rice, PR|NA-US-PR-URB EUGE...|        false|           NULL|               NULL|      NULL|         NULL|
# |       39827|  85209|   STANDARD|               MESA|   AZ|       PRIMARY|33.37|-111.64| -0.3|-0.77| 0.55|         NA|     US|            Mesa, AZ|       NA-US-AZ-MESA|        false|          14962|              26883| 563792730|no NWS data, |
# |       39828|  85210|   STANDARD|               MESA|   AZ|       PRIMARY|33.38|-111.84|-0.31|-0.77| 0.55|         NA|     US|            Mesa, AZ|       NA-US-AZ-MESA|        false|          14374|              25446| 471000465|         NULL|
# |       49345|  32046|   STANDARD|           HILLIARD|   FL|       PRIMARY|30.69| -81.92| 0.12|-0.85| 0.51|         NA|     US|        Hilliard, FL|   NA-US-FL-HILLIARD|        false|           3922|               7443| 133112149|         NULL|
# |       49346|  34445|     PO BOX|             HOLDER|   FL|       PRIMARY|28.96| -82.41| 0.11|-0.86| 0.48|         NA|     US|          Holder, FL|     NA-US-FL-HOLDER|        false|           NULL|               NULL|      NULL|         NULL|
# |       49347|  32564|   STANDARD|               HOLT|   FL|       PRIMARY|30.72| -86.67| 0.04|-0.85| 0.51|         NA|     US|            Holt, FL|       NA-US-FL-HOLT|        false|           1207|               2190|  36395913|         NULL|
# |       49348|  34487|     PO BOX|          HOMOSASSA|   FL|       PRIMARY|28.78| -82.61| 0.11|-0.86| 0.48|         NA|     US|       Homosassa, FL|  NA-US-FL-HOMOSASSA|        false|           NULL|               NULL|      NULL|         NULL|
# |          10|    708|   STANDARD|       BDA SAN LUIS|   PR|NOT ACCEPTABLE|18.14| -66.26| 0.38|-0.86| 0.31|         NA|     US|    Bda San Luis, PR|NA-US-PR-BDA SAN ...|        false|           NULL|               NULL|      NULL|         NULL|
# |           3|    704|   STANDARD|      SECT LANAUSSE|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US|   Sect Lanausse, PR|NA-US-PR-SECT LAN...|        false|           NULL|               NULL|      NULL|         NULL|
# |       54354|  36275|     PO BOX|      SPRING GARDEN|   AL|       PRIMARY|33.97| -85.55| 0.06|-0.82| 0.55|         NA|     US|   Spring Garden, AL|NA-US-AL-SPRING G...|        false|           NULL|               NULL|      NULL|         NULL|
# |       54355|  35146|   STANDARD|        SPRINGVILLE|   AL|       PRIMARY|33.77| -86.47| 0.05|-0.82| 0.55|         NA|     US|     Springville, AL|NA-US-AL-SPRINGVILLE|        false|           4046|               7845| 172127599|         NULL|
# |       54356|  35585|   STANDARD|        SPRUCE PINE|   AL|       PRIMARY|34.37| -87.69| 0.03|-0.82| 0.56|         NA|     US|     Spruce Pine, AL|NA-US-AL-SPRUCE PINE|        false|            610|               1209|  18525517|         NULL|
# |       76511|  27007|   STANDARD|           ASH HILL|   NC|NOT ACCEPTABLE| 36.4| -80.56| 0.13|-0.79| 0.59|         NA|     US|        Ash Hill, NC|   NA-US-NC-ASH HILL|        false|            842|               1666|  28876493|         NULL|
# |       76512|  27203|   STANDARD|           ASHEBORO|   NC|       PRIMARY|35.71| -79.81| 0.14|-0.79| 0.58|         NA|     US|        Asheboro, NC|   NA-US-NC-ASHEBORO|        false|           8355|              15228| 215474318|         NULL|
# +------------+-------+-----------+-------------------+-----+--------------+-----+-------+-----+-----+-----+-----------+-------+--------------------+--------------------+-------------+---------------+-------------------+----------+-------------+
# only showing top 20 rows

# %%
zip_code_df.printSchema()
# Out:
# root
#  |-- RecordNumber: integer (nullable = true)
#  |-- Zipcode: integer (nullable = true)
#  |-- ZipCodeType: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- LocationType: string (nullable = true)
#  |-- Lat: double (nullable = true)
#  |-- Long: double (nullable = true)
#  |-- Xaxis: double (nullable = true)
#  |-- Yaxis: double (nullable = true)
#  |-- Zaxis: double (nullable = true)
#  |-- WorldRegion: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- LocationText: string (nullable = true)
#  |-- Location: string (nullable = true)
#  |-- Decommisioned: boolean (nullable = true)
#  |-- TaxReturnsFiled: integer (nullable = true)
#  |-- EstimatedPopulation: integer (nullable = true)
#  |-- TotalWages: integer (nullable = true)
#  |-- Notes: string (nullable = true)

# %%
zip_code_df.select('RecordNumber','ZipCode','State').show()
# Out:
# +------------+-------+-----+
# |RecordNumber|ZipCode|State|
# +------------+-------+-----+
# |           1|    704|   PR|
# |           2|    704|   PR|
# |          10|    709|   PR|
# |       61391|  76166|   TX|
# |       61392|  76177|   TX|
# |       61393|  76177|   TX|
# |           4|    704|   PR|
# |       39827|  85209|   AZ|
# |       39828|  85210|   AZ|
# |       49345|  32046|   FL|
# |       49346|  34445|   FL|
# |       49347|  32564|   FL|
# |       49348|  34487|   FL|
# |          10|    708|   PR|
# |           3|    704|   PR|
# |       54354|  36275|   AL|
# |       54355|  35146|   AL|
# |       54356|  35585|   AL|
# |       76511|  27007|   NC|
# |       76512|  27203|   NC|
# +------------+-------+-----+
# only showing top 20 rows

# %%
zip_code_df.describe().show()
# Out:
# +-------+-----------------+-----------------+-----------+---------------+-----+------------+-----------------+------------------+-------------------+-------------------+-------------------+-----------+-------+-------------------+--------------------+-----------------+-------------------+--------------------+-------------+
# |summary|     RecordNumber|          Zipcode|ZipCodeType|           City|State|LocationType|              Lat|              Long|              Xaxis|              Yaxis|              Zaxis|WorldRegion|Country|       LocationText|            Location|  TaxReturnsFiled|EstimatedPopulation|          TotalWages|        Notes|
# +-------+-----------------+-----------------+-----------+---------------+-----+------------+-----------------+------------------+-------------------+-------------------+-------------------+-----------+-------+-------------------+--------------------+-----------------+-------------------+--------------------+-------------+
# |  count|               21|               21|         21|             21|   21|          21|               21|                21|                 21|                 21|                 21|         21|     21|                 21|                  21|               11|                 11|                  11|            1|
# |   mean|40659.42857142857|34530.19047619047|       NULL|           NULL| NULL|        NULL| 28.6747619047619|-83.15952380952379|0.10952380952380954|-0.8323809523809522|0.47285714285714286|       NULL|   NULL|               NULL|                NULL|4873.181818181818|  8893.818181818182| 1.740383299090909E8|         NULL|
# | stddev|28220.90159362636|29480.87406204071|       NULL|           NULL| NULL|        NULL|7.170747254678286|14.205006679403738| 0.2160897080028614|0.03389760491609428|0.11336414147087506|       NULL|   NULL|               NULL|                NULL|5324.035345828986|  9455.758317746724|1.8266912149795327E8|         NULL|
# |    min|                1|              704|     PO BOX|       ASH HILL|   AL|  ACCEPTABLE|            17.96|           -111.84|              -0.31|              -0.87|                0.3|         NA|     US|       Ash Hill, NC|NA-US-AL-SPRING G...|              610|               1209|            18525517|no NWS data, |
# |    max|            76513|            85210|     UNIQUE|URB EUGENE RICE|   TX|     PRIMARY|             36.4|            -66.22|               0.38|              -0.77|               0.59|         NA|     US|Urb Eugene Rice, PR|   NA-US-TX-FT WORTH|            14962|              26883|           563792730|no NWS data, |
# +-------+-----------------+-----------------+-----------+---------------+-----+------------+-----------------+------------------+-------------------+-------------------+-------------------+-----------+-------+-------------------+--------------------+-----------------+-------------------+--------------------+-------------+

# %%
from pyspark.sql.functions import concat, lit
## Add new column
zip_code_df.withColumn('State(ST)',  concat(lit('ST-'),zip_code_df['State'])).show()
# Out:
# +------------+-------+-----------+-------------------+-----+--------------+-----+-------+-----+-----+-----+-----------+-------+--------------------+--------------------+-------------+---------------+-------------------+----------+-------------+---------+
# |RecordNumber|Zipcode|ZipCodeType|               City|State|  LocationType|  Lat|   Long|Xaxis|Yaxis|Zaxis|WorldRegion|Country|        LocationText|            Location|Decommisioned|TaxReturnsFiled|EstimatedPopulation|TotalWages|        Notes|State(ST)|
# +------------+-------+-----------+-------------------+-----+--------------+-----+-------+-----+-----+-----+-----------+-------+--------------------+--------------------+-------------+---------------+-------------------+----------+-------------+---------+
# |           1|    704|   STANDARD|        PARC PARQUE|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US|     Parc Parque, PR|NA-US-PR-PARC PARQUE|        false|           NULL|               NULL|      NULL|         NULL|    ST-PR|
# |           2|    704|   STANDARD|PASEO COSTA DEL SUR|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US|Paseo Costa Del S...|NA-US-PR-PASEO CO...|        false|           NULL|               NULL|      NULL|         NULL|    ST-PR|
# |          10|    709|   STANDARD|       BDA SAN LUIS|   PR|NOT ACCEPTABLE|18.14| -66.26| 0.38|-0.86| 0.31|         NA|     US|    Bda San Luis, PR|NA-US-PR-BDA SAN ...|        false|           NULL|               NULL|      NULL|         NULL|    ST-PR|
# |       61391|  76166|     UNIQUE|  CINGULAR WIRELESS|   TX|NOT ACCEPTABLE|32.72| -97.31| -0.1|-0.83| 0.54|         NA|     US|Cingular Wireless...|NA-US-TX-CINGULAR...|        false|           NULL|               NULL|      NULL|         NULL|    ST-TX|
# |       61392|  76177|   STANDARD|         FORT WORTH|   TX|       PRIMARY|32.75| -97.33| -0.1|-0.83| 0.54|         NA|     US|      Fort Worth, TX| NA-US-TX-FORT WORTH|        false|           2126|               4053| 122396986|         NULL|    ST-TX|
# |       61393|  76177|   STANDARD|           FT WORTH|   TX|    ACCEPTABLE|32.75| -97.33| -0.1|-0.83| 0.54|         NA|     US|        Ft Worth, TX|   NA-US-TX-FT WORTH|        false|           2126|               4053| 122396986|         NULL|    ST-TX|
# |           4|    704|   STANDARD|    URB EUGENE RICE|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US| Urb Eugene Rice, PR|NA-US-PR-URB EUGE...|        false|           NULL|               NULL|      NULL|         NULL|    ST-PR|
# |       39827|  85209|   STANDARD|               MESA|   AZ|       PRIMARY|33.37|-111.64| -0.3|-0.77| 0.55|         NA|     US|            Mesa, AZ|       NA-US-AZ-MESA|        false|          14962|              26883| 563792730|no NWS data, |    ST-AZ|
# |       39828|  85210|   STANDARD|               MESA|   AZ|       PRIMARY|33.38|-111.84|-0.31|-0.77| 0.55|         NA|     US|            Mesa, AZ|       NA-US-AZ-MESA|        false|          14374|              25446| 471000465|         NULL|    ST-AZ|
# |       49345|  32046|   STANDARD|           HILLIARD|   FL|       PRIMARY|30.69| -81.92| 0.12|-0.85| 0.51|         NA|     US|        Hilliard, FL|   NA-US-FL-HILLIARD|        false|           3922|               7443| 133112149|         NULL|    ST-FL|
# |       49346|  34445|     PO BOX|             HOLDER|   FL|       PRIMARY|28.96| -82.41| 0.11|-0.86| 0.48|         NA|     US|          Holder, FL|     NA-US-FL-HOLDER|        false|           NULL|               NULL|      NULL|         NULL|    ST-FL|
# |       49347|  32564|   STANDARD|               HOLT|   FL|       PRIMARY|30.72| -86.67| 0.04|-0.85| 0.51|         NA|     US|            Holt, FL|       NA-US-FL-HOLT|        false|           1207|               2190|  36395913|         NULL|    ST-FL|
# |       49348|  34487|     PO BOX|          HOMOSASSA|   FL|       PRIMARY|28.78| -82.61| 0.11|-0.86| 0.48|         NA|     US|       Homosassa, FL|  NA-US-FL-HOMOSASSA|        false|           NULL|               NULL|      NULL|         NULL|    ST-FL|
# |          10|    708|   STANDARD|       BDA SAN LUIS|   PR|NOT ACCEPTABLE|18.14| -66.26| 0.38|-0.86| 0.31|         NA|     US|    Bda San Luis, PR|NA-US-PR-BDA SAN ...|        false|           NULL|               NULL|      NULL|         NULL|    ST-PR|
# |           3|    704|   STANDARD|      SECT LANAUSSE|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US|   Sect Lanausse, PR|NA-US-PR-SECT LAN...|        false|           NULL|               NULL|      NULL|         NULL|    ST-PR|
# |       54354|  36275|     PO BOX|      SPRING GARDEN|   AL|       PRIMARY|33.97| -85.55| 0.06|-0.82| 0.55|         NA|     US|   Spring Garden, AL|NA-US-AL-SPRING G...|        false|           NULL|               NULL|      NULL|         NULL|    ST-AL|
# |       54355|  35146|   STANDARD|        SPRINGVILLE|   AL|       PRIMARY|33.77| -86.47| 0.05|-0.82| 0.55|         NA|     US|     Springville, AL|NA-US-AL-SPRINGVILLE|        false|           4046|               7845| 172127599|         NULL|    ST-AL|
# |       54356|  35585|   STANDARD|        SPRUCE PINE|   AL|       PRIMARY|34.37| -87.69| 0.03|-0.82| 0.56|         NA|     US|     Spruce Pine, AL|NA-US-AL-SPRUCE PINE|        false|            610|               1209|  18525517|         NULL|    ST-AL|
# |       76511|  27007|   STANDARD|           ASH HILL|   NC|NOT ACCEPTABLE| 36.4| -80.56| 0.13|-0.79| 0.59|         NA|     US|        Ash Hill, NC|   NA-US-NC-ASH HILL|        false|            842|               1666|  28876493|         NULL|    ST-NC|
# |       76512|  27203|   STANDARD|           ASHEBORO|   NC|       PRIMARY|35.71| -79.81| 0.14|-0.79| 0.58|         NA|     US|        Asheboro, NC|   NA-US-NC-ASHEBORO|        false|           8355|              15228| 215474318|         NULL|    ST-NC|
# +------------+-------+-----------+-------------------+-----+--------------+-----+-------+-----+-----+-----+-----------+-------+--------------------+--------------------+-------------+---------------+-------------------+----------+-------------+---------+
# only showing top 20 rows

# %%
# Drop column
zip_code_df.drop('State(ST)').show()
# Out:
# +------------+-------+-----------+-------------------+-----+--------------+-----+-------+-----+-----+-----+-----------+-------+--------------------+--------------------+-------------+---------------+-------------------+----------+-------------+
# |RecordNumber|Zipcode|ZipCodeType|               City|State|  LocationType|  Lat|   Long|Xaxis|Yaxis|Zaxis|WorldRegion|Country|        LocationText|            Location|Decommisioned|TaxReturnsFiled|EstimatedPopulation|TotalWages|        Notes|
# +------------+-------+-----------+-------------------+-----+--------------+-----+-------+-----+-----+-----+-----------+-------+--------------------+--------------------+-------------+---------------+-------------------+----------+-------------+
# |           1|    704|   STANDARD|        PARC PARQUE|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US|     Parc Parque, PR|NA-US-PR-PARC PARQUE|        false|           NULL|               NULL|      NULL|         NULL|
# |           2|    704|   STANDARD|PASEO COSTA DEL SUR|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US|Paseo Costa Del S...|NA-US-PR-PASEO CO...|        false|           NULL|               NULL|      NULL|         NULL|
# |          10|    709|   STANDARD|       BDA SAN LUIS|   PR|NOT ACCEPTABLE|18.14| -66.26| 0.38|-0.86| 0.31|         NA|     US|    Bda San Luis, PR|NA-US-PR-BDA SAN ...|        false|           NULL|               NULL|      NULL|         NULL|
# |       61391|  76166|     UNIQUE|  CINGULAR WIRELESS|   TX|NOT ACCEPTABLE|32.72| -97.31| -0.1|-0.83| 0.54|         NA|     US|Cingular Wireless...|NA-US-TX-CINGULAR...|        false|           NULL|               NULL|      NULL|         NULL|
# |       61392|  76177|   STANDARD|         FORT WORTH|   TX|       PRIMARY|32.75| -97.33| -0.1|-0.83| 0.54|         NA|     US|      Fort Worth, TX| NA-US-TX-FORT WORTH|        false|           2126|               4053| 122396986|         NULL|
# |       61393|  76177|   STANDARD|           FT WORTH|   TX|    ACCEPTABLE|32.75| -97.33| -0.1|-0.83| 0.54|         NA|     US|        Ft Worth, TX|   NA-US-TX-FT WORTH|        false|           2126|               4053| 122396986|         NULL|
# |           4|    704|   STANDARD|    URB EUGENE RICE|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US| Urb Eugene Rice, PR|NA-US-PR-URB EUGE...|        false|           NULL|               NULL|      NULL|         NULL|
# |       39827|  85209|   STANDARD|               MESA|   AZ|       PRIMARY|33.37|-111.64| -0.3|-0.77| 0.55|         NA|     US|            Mesa, AZ|       NA-US-AZ-MESA|        false|          14962|              26883| 563792730|no NWS data, |
# |       39828|  85210|   STANDARD|               MESA|   AZ|       PRIMARY|33.38|-111.84|-0.31|-0.77| 0.55|         NA|     US|            Mesa, AZ|       NA-US-AZ-MESA|        false|          14374|              25446| 471000465|         NULL|
# |       49345|  32046|   STANDARD|           HILLIARD|   FL|       PRIMARY|30.69| -81.92| 0.12|-0.85| 0.51|         NA|     US|        Hilliard, FL|   NA-US-FL-HILLIARD|        false|           3922|               7443| 133112149|         NULL|
# |       49346|  34445|     PO BOX|             HOLDER|   FL|       PRIMARY|28.96| -82.41| 0.11|-0.86| 0.48|         NA|     US|          Holder, FL|     NA-US-FL-HOLDER|        false|           NULL|               NULL|      NULL|         NULL|
# |       49347|  32564|   STANDARD|               HOLT|   FL|       PRIMARY|30.72| -86.67| 0.04|-0.85| 0.51|         NA|     US|            Holt, FL|       NA-US-FL-HOLT|        false|           1207|               2190|  36395913|         NULL|
# |       49348|  34487|     PO BOX|          HOMOSASSA|   FL|       PRIMARY|28.78| -82.61| 0.11|-0.86| 0.48|         NA|     US|       Homosassa, FL|  NA-US-FL-HOMOSASSA|        false|           NULL|               NULL|      NULL|         NULL|
# |          10|    708|   STANDARD|       BDA SAN LUIS|   PR|NOT ACCEPTABLE|18.14| -66.26| 0.38|-0.86| 0.31|         NA|     US|    Bda San Luis, PR|NA-US-PR-BDA SAN ...|        false|           NULL|               NULL|      NULL|         NULL|
# |           3|    704|   STANDARD|      SECT LANAUSSE|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US|   Sect Lanausse, PR|NA-US-PR-SECT LAN...|        false|           NULL|               NULL|      NULL|         NULL|
# |       54354|  36275|     PO BOX|      SPRING GARDEN|   AL|       PRIMARY|33.97| -85.55| 0.06|-0.82| 0.55|         NA|     US|   Spring Garden, AL|NA-US-AL-SPRING G...|        false|           NULL|               NULL|      NULL|         NULL|
# |       54355|  35146|   STANDARD|        SPRINGVILLE|   AL|       PRIMARY|33.77| -86.47| 0.05|-0.82| 0.55|         NA|     US|     Springville, AL|NA-US-AL-SPRINGVILLE|        false|           4046|               7845| 172127599|         NULL|
# |       54356|  35585|   STANDARD|        SPRUCE PINE|   AL|       PRIMARY|34.37| -87.69| 0.03|-0.82| 0.56|         NA|     US|     Spruce Pine, AL|NA-US-AL-SPRUCE PINE|        false|            610|               1209|  18525517|         NULL|
# |       76511|  27007|   STANDARD|           ASH HILL|   NC|NOT ACCEPTABLE| 36.4| -80.56| 0.13|-0.79| 0.59|         NA|     US|        Ash Hill, NC|   NA-US-NC-ASH HILL|        false|            842|               1666|  28876493|         NULL|
# |       76512|  27203|   STANDARD|           ASHEBORO|   NC|       PRIMARY|35.71| -79.81| 0.14|-0.79| 0.58|         NA|     US|        Asheboro, NC|   NA-US-NC-ASHEBORO|        false|           8355|              15228| 215474318|         NULL|
# +------------+-------+-----------+-------------------+-----+--------------+-----+-------+-----+-----+-----+-----------+-------+--------------------+--------------------+-------------+---------------+-------------------+----------+-------------+
# only showing top 20 rows

# %%
# Rename column

zip_code_df.withColumnRenamed('ZipCode', 'Zip').show()
# Out:
# +------------+-----+-----------+-------------------+-----+--------------+-----+-------+-----+-----+-----+-----------+-------+--------------------+--------------------+-------------+---------------+-------------------+----------+-------------+
# |RecordNumber|  Zip|ZipCodeType|               City|State|  LocationType|  Lat|   Long|Xaxis|Yaxis|Zaxis|WorldRegion|Country|        LocationText|            Location|Decommisioned|TaxReturnsFiled|EstimatedPopulation|TotalWages|        Notes|
# +------------+-----+-----------+-------------------+-----+--------------+-----+-------+-----+-----+-----+-----------+-------+--------------------+--------------------+-------------+---------------+-------------------+----------+-------------+
# |           1|  704|   STANDARD|        PARC PARQUE|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US|     Parc Parque, PR|NA-US-PR-PARC PARQUE|        false|           NULL|               NULL|      NULL|         NULL|
# |           2|  704|   STANDARD|PASEO COSTA DEL SUR|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US|Paseo Costa Del S...|NA-US-PR-PASEO CO...|        false|           NULL|               NULL|      NULL|         NULL|
# |          10|  709|   STANDARD|       BDA SAN LUIS|   PR|NOT ACCEPTABLE|18.14| -66.26| 0.38|-0.86| 0.31|         NA|     US|    Bda San Luis, PR|NA-US-PR-BDA SAN ...|        false|           NULL|               NULL|      NULL|         NULL|
# |       61391|76166|     UNIQUE|  CINGULAR WIRELESS|   TX|NOT ACCEPTABLE|32.72| -97.31| -0.1|-0.83| 0.54|         NA|     US|Cingular Wireless...|NA-US-TX-CINGULAR...|        false|           NULL|               NULL|      NULL|         NULL|
# |       61392|76177|   STANDARD|         FORT WORTH|   TX|       PRIMARY|32.75| -97.33| -0.1|-0.83| 0.54|         NA|     US|      Fort Worth, TX| NA-US-TX-FORT WORTH|        false|           2126|               4053| 122396986|         NULL|
# |       61393|76177|   STANDARD|           FT WORTH|   TX|    ACCEPTABLE|32.75| -97.33| -0.1|-0.83| 0.54|         NA|     US|        Ft Worth, TX|   NA-US-TX-FT WORTH|        false|           2126|               4053| 122396986|         NULL|
# |           4|  704|   STANDARD|    URB EUGENE RICE|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US| Urb Eugene Rice, PR|NA-US-PR-URB EUGE...|        false|           NULL|               NULL|      NULL|         NULL|
# |       39827|85209|   STANDARD|               MESA|   AZ|       PRIMARY|33.37|-111.64| -0.3|-0.77| 0.55|         NA|     US|            Mesa, AZ|       NA-US-AZ-MESA|        false|          14962|              26883| 563792730|no NWS data, |
# |       39828|85210|   STANDARD|               MESA|   AZ|       PRIMARY|33.38|-111.84|-0.31|-0.77| 0.55|         NA|     US|            Mesa, AZ|       NA-US-AZ-MESA|        false|          14374|              25446| 471000465|         NULL|
# |       49345|32046|   STANDARD|           HILLIARD|   FL|       PRIMARY|30.69| -81.92| 0.12|-0.85| 0.51|         NA|     US|        Hilliard, FL|   NA-US-FL-HILLIARD|        false|           3922|               7443| 133112149|         NULL|
# |       49346|34445|     PO BOX|             HOLDER|   FL|       PRIMARY|28.96| -82.41| 0.11|-0.86| 0.48|         NA|     US|          Holder, FL|     NA-US-FL-HOLDER|        false|           NULL|               NULL|      NULL|         NULL|
# |       49347|32564|   STANDARD|               HOLT|   FL|       PRIMARY|30.72| -86.67| 0.04|-0.85| 0.51|         NA|     US|            Holt, FL|       NA-US-FL-HOLT|        false|           1207|               2190|  36395913|         NULL|
# |       49348|34487|     PO BOX|          HOMOSASSA|   FL|       PRIMARY|28.78| -82.61| 0.11|-0.86| 0.48|         NA|     US|       Homosassa, FL|  NA-US-FL-HOMOSASSA|        false|           NULL|               NULL|      NULL|         NULL|
# |          10|  708|   STANDARD|       BDA SAN LUIS|   PR|NOT ACCEPTABLE|18.14| -66.26| 0.38|-0.86| 0.31|         NA|     US|    Bda San Luis, PR|NA-US-PR-BDA SAN ...|        false|           NULL|               NULL|      NULL|         NULL|
# |           3|  704|   STANDARD|      SECT LANAUSSE|   PR|NOT ACCEPTABLE|17.96| -66.22| 0.38|-0.87|  0.3|         NA|     US|   Sect Lanausse, PR|NA-US-PR-SECT LAN...|        false|           NULL|               NULL|      NULL|         NULL|
# |       54354|36275|     PO BOX|      SPRING GARDEN|   AL|       PRIMARY|33.97| -85.55| 0.06|-0.82| 0.55|         NA|     US|   Spring Garden, AL|NA-US-AL-SPRING G...|        false|           NULL|               NULL|      NULL|         NULL|
# |       54355|35146|   STANDARD|        SPRINGVILLE|   AL|       PRIMARY|33.77| -86.47| 0.05|-0.82| 0.55|         NA|     US|     Springville, AL|NA-US-AL-SPRINGVILLE|        false|           4046|               7845| 172127599|         NULL|
# |       54356|35585|   STANDARD|        SPRUCE PINE|   AL|       PRIMARY|34.37| -87.69| 0.03|-0.82| 0.56|         NA|     US|     Spruce Pine, AL|NA-US-AL-SPRUCE PINE|        false|            610|               1209|  18525517|         NULL|
# |       76511|27007|   STANDARD|           ASH HILL|   NC|NOT ACCEPTABLE| 36.4| -80.56| 0.13|-0.79| 0.59|         NA|     US|        Ash Hill, NC|   NA-US-NC-ASH HILL|        false|            842|               1666|  28876493|         NULL|
# |       76512|27203|   STANDARD|           ASHEBORO|   NC|       PRIMARY|35.71| -79.81| 0.14|-0.79| 0.58|         NA|     US|        Asheboro, NC|   NA-US-NC-ASHEBORO|        false|           8355|              15228| 215474318|         NULL|
# +------------+-----+-----------+-------------------+-----+--------------+-----+-------+-----+-----+-----+-----------+-------+--------------------+--------------------+-------------+---------------+-------------------+----------+-------------+
# only showing top 20 rows

# %%
# Delete NULL Row
clean_df = zip_code_df.na.drop(how='all',subset=['TaxReturnsFiled', 'EstimatedPopulation','TotalWages','Notes'])
clean_df.show()
# Out:
# +------------+-------+-----------+-----------+-----+--------------+-----+-------+-----+-----+-----+-----------+-------+---------------+--------------------+-------------+---------------+-------------------+----------+-------------+
# |RecordNumber|Zipcode|ZipCodeType|       City|State|  LocationType|  Lat|   Long|Xaxis|Yaxis|Zaxis|WorldRegion|Country|   LocationText|            Location|Decommisioned|TaxReturnsFiled|EstimatedPopulation|TotalWages|        Notes|
# +------------+-------+-----------+-----------+-----+--------------+-----+-------+-----+-----+-----+-----------+-------+---------------+--------------------+-------------+---------------+-------------------+----------+-------------+
# |       61392|  76177|   STANDARD| FORT WORTH|   TX|       PRIMARY|32.75| -97.33| -0.1|-0.83| 0.54|         NA|     US| Fort Worth, TX| NA-US-TX-FORT WORTH|        false|           2126|               4053| 122396986|         NULL|
# |       61393|  76177|   STANDARD|   FT WORTH|   TX|    ACCEPTABLE|32.75| -97.33| -0.1|-0.83| 0.54|         NA|     US|   Ft Worth, TX|   NA-US-TX-FT WORTH|        false|           2126|               4053| 122396986|         NULL|
# |       39827|  85209|   STANDARD|       MESA|   AZ|       PRIMARY|33.37|-111.64| -0.3|-0.77| 0.55|         NA|     US|       Mesa, AZ|       NA-US-AZ-MESA|        false|          14962|              26883| 563792730|no NWS data, |
# |       39828|  85210|   STANDARD|       MESA|   AZ|       PRIMARY|33.38|-111.84|-0.31|-0.77| 0.55|         NA|     US|       Mesa, AZ|       NA-US-AZ-MESA|        false|          14374|              25446| 471000465|         NULL|
# |       49345|  32046|   STANDARD|   HILLIARD|   FL|       PRIMARY|30.69| -81.92| 0.12|-0.85| 0.51|         NA|     US|   Hilliard, FL|   NA-US-FL-HILLIARD|        false|           3922|               7443| 133112149|         NULL|
# |       49347|  32564|   STANDARD|       HOLT|   FL|       PRIMARY|30.72| -86.67| 0.04|-0.85| 0.51|         NA|     US|       Holt, FL|       NA-US-FL-HOLT|        false|           1207|               2190|  36395913|         NULL|
# |       54355|  35146|   STANDARD|SPRINGVILLE|   AL|       PRIMARY|33.77| -86.47| 0.05|-0.82| 0.55|         NA|     US|Springville, AL|NA-US-AL-SPRINGVILLE|        false|           4046|               7845| 172127599|         NULL|
# |       54356|  35585|   STANDARD|SPRUCE PINE|   AL|       PRIMARY|34.37| -87.69| 0.03|-0.82| 0.56|         NA|     US|Spruce Pine, AL|NA-US-AL-SPRUCE PINE|        false|            610|               1209|  18525517|         NULL|
# |       76511|  27007|   STANDARD|   ASH HILL|   NC|NOT ACCEPTABLE| 36.4| -80.56| 0.13|-0.79| 0.59|         NA|     US|   Ash Hill, NC|   NA-US-NC-ASH HILL|        false|            842|               1666|  28876493|         NULL|
# |       76512|  27203|   STANDARD|   ASHEBORO|   NC|       PRIMARY|35.71| -79.81| 0.14|-0.79| 0.58|         NA|     US|   Asheboro, NC|   NA-US-NC-ASHEBORO|        false|           8355|              15228| 215474318|         NULL|
# |       76513|  27204|     PO BOX|   ASHEBORO|   NC|       PRIMARY|35.71| -79.81| 0.14|-0.79| 0.58|         NA|     US|   Asheboro, NC|   NA-US-NC-ASHEBORO|        false|           1035|               1816|  30322473|         NULL|
# +------------+-------+-----------+-----------+-----+--------------+-----+-------+-----+-----+-----+-----------+-------+---------------+--------------------+-------------+---------------+-------------------+----------+-------------+

# %%
from pyspark.sql.functions import sum as _sum, col, round, avg, regexp_replace
# Top 3 thanh pho co tien luong cao nhat
clean_df.groupBy('City').agg(_sum('TotalWages').alias('Total Wages')).orderBy('Total Wages', ascending=False).limit(3).show()
# Out:
# +-----------+-----------+
# |       City|Total Wages|
# +-----------+-----------+
# |       MESA| 1034793195|
# |   ASHEBORO|  245796791|
# |SPRINGVILLE|  172127599|
# +-----------+-----------+

# %%
# % Dan so da nop to khai thue tren tong dan so uoc tinh
avg_tax_return = clean_df.groupBy('City').agg(_sum('EstimatedPopulation').alias('TotalPopulation'), _sum('TaxReturnsFiled').alias('TotalTaxFiledReturn')).withColumn('TaxFilledPercent', round((col('TotalTaxFiledReturn') / col('TotalPopulation')) * 100, 2)).withColumn('TaxFilledPercent', concat(col('TaxFilledPercent'),lit(' %'))).orderBy('TaxFilledPercent', ascending=False)

avg_tax_return.toPandas()
# Out:
#           City  TotalPopulation  TotalTaxFiledReturn TaxFilledPercent
# 0         MESA            52329                29336          56.06 %
# 1         HOLT             2190                 1207          55.11 %
# 2     ASHEBORO            17044                 9390          55.09 %
# 3     HILLIARD             7443                 3922          52.69 %
# 4     FT WORTH             4053                 2126          52.45 %
# 5   FORT WORTH             4053                 2126          52.45 %
# 6  SPRINGVILLE             7845                 4046          51.57 %
# 7     ASH HILL             1666                  842          50.54 %
# 8  SPRUCE PINE             1209                  610          50.45 %

# %%
format_df = avg_tax_return.withColumn('TaxFilledPercent', regexp_replace('TaxFilledPercent', '%', '').cast('float')).select(round(avg('TaxFilledPercent'),2).alias('AverageTaxFilledPercent'))
format_df.toPandas()
# Out:
#    AverageTaxFilledPercent
# 0                    52.93
